# %% [markdown]
# ##Import libraries

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.1+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.14.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
import torchvision
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, utils
from PIL import Image
import torch.utils.data as data
import torch.nn as nn
import torchvision.models as models
import torch.nn.functional as F
import torch.optim as optim
import cv2


# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Data loading
#
#
# This part of the code creates a PyTorch dataset object called NYUDataset for loading the NYU Depth v2 dataset.
# <br>
# <br>
# The __init__ function defines some class attributes that will be used later when loading the data.
# <br>
#
#     *   `self.root_dir`: The directory path where the NYU Depth v2 dataset is located.
#     *   `self.split`: A string indicating whether to load the "train" or "test" split of the dataset.
#     *   `self.transform`: A transformation to be applied to the RGB and depth images (e.g., resizing, normalizing).
#     *   `self.rgb_files`: A list of file paths to the RGB image files, sorted in ascending order.
#     *   `self.depth_files`: A list of file paths to the depth image files, sorted in ascending order.
#
#
# The __len__ method returns the length of the self.rgb_files list, which is equivalent to the number of images in the dataset split.
# <br>
# <br>
# The __getitem__ method takes an index idx as input and returns the RGB and depth images as numpy arrays, after applying the specified transformations.

# %%
class NYUDataset(torch.utils.data.Dataset):

    def __init__(self, transform=None):
        self.root_dir = os.getcwd()

        self.rgb_files = []
        self.depth_files = []

        for subdir, dirs, files in os.walk(self.root_dir):
            for file in files:
                if 'rgb' in file:
                    self.rgb_files.append(os.path.join(subdir, file))
                elif 'depth' in file:
                    self.depth_files.append(os.path.join(subdir, file))

        self.transform = transform

    def __len__(self):
        return len(self.rgb_files)

    def __getitem__(self, idx):
        rgb = Image.open(self.rgb_files[idx])
        depth = Image.open(self.depth_files[idx])

        if self.transform:
            rgb = self.transform(rgb)
            depth = self.transform(depth)
        return rgb, depth

# %% [markdown]
# ##Data Pre-processing
#
# A set of transformations to apply to the RGB and depth images.
# The ToTensor() function will convert the RGB and depth images to PyTorch tensors and scale the pixel values between 0 and 1, which is the desired range for optimal model training.
# <br>
# <br>
# The dataset is then split into a train set and test set using an 80-20 split, and dataloader objects are created for each set. The train dataloader randomly shuffles the data during each epoch, while the test dataloader does not shuffle the data. Both dataloaders use four worker threads to load the data in parallel.

# %%
# %cd "drive/MyDrive/Final project/dataset"

# Define the transforms
transform = transforms.Compose([
    transforms.Resize((240, 320)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.float() / 255) # normalize the image by dividing by 255
])


# Initialize the dataset and data loader
nyu_dataset = NYUDataset(transform = transform)

# Access a sample RGB image and print its shape and data type
rgb_image = nyu_dataset[0][0]
print(rgb_image.shape)
print(rgb_image.dtype)


# Access a sample depth image and print its shape and data type

depth_image = nyu_dataset[0][1]
print(depth_image.shape)
print(depth_image.dtype)

print(len(nyu_dataset))
# Out:
# /content/drive/MyDrive/Final project/dataset
# torch.Size([3, 240, 320])
# torch.float32
# torch.Size([1, 240, 320])
# torch.float32
# 36396

# %%
# Split the dataset into train, validation, and test sets
train_size = int(0.8 * len(nyu_dataset))
val_size = len(nyu_dataset) - train_size
train_dataset, val_dataset = random_split(nyu_dataset, [train_size, val_size])


# Create the train, validation, and test dataloader objects
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False)


print(val_size)
print(train_size)
# Out:
# 7280
# 29116

# %% [markdown]
# ##Model definition
#
# In this code, we import the ResNet-50 model from torchvision.models, which is a pre-trained CNN on ImageNet. We then set the pretrained argument to True to load the pre-trained weights of the model. Finally, we loop through all the parameters of the model and set requires_grad to False to freeze the weights, which means that we will not update them during training.

# %%
class DepthEstimationModel(nn.Module):
    def __init__(self):
        super(DepthEstimationModel, self).__init__()

        # Load pre-trained ResNet18 model
        self.encoder = models.resnet18()
        self.encoder_tail = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1),
            nn.Upsample(size=(240, 320))
        )

    def forward(self, x):
        # Forward pass through encoder
        x = self.encoder.conv1(x)
        x = self.encoder.bn1(x)
        x = self.encoder.relu(x)
        x = self.encoder.maxpool(x)

        x = self.encoder.layer1(x)
        x = self.encoder.layer2(x)
        x = self.encoder.layer3(x)
        x = self.encoder.layer4(x)

        # Forward pass through decoder
        x = self.encoder_tail(x)
        x = self.decoder(x)


        return x

# %% [markdown]
# ##Define the loss functions
#
# Define the loss function  between the predicted depth map and the ground truth depth map.

# %%
def depth_loss(depth_pred, depth_true):
    # Calculate the loss between predicted depth and ground truth depth

    # Calculate RMSE
    rmse = torch.sqrt(F.mse_loss(depth_pred, depth_true))

    # Calculate abs rel
    #abs_rel = torch.mean(torch.abs(depth_pred - depth_true) / depth_true)

    # Calculate threshold
    #max_ratio = torch.max(depth_pred / depth_true, depth_true / depth_pred)

    #threshold = torch.mean((max_ratio < 1.25).float())

    return  rmse

# %% [markdown]
# ##Model Training and Evaluation
#
# In this code, we first define the optimizer as Adam with a learning rate of 0.001. Then we define the number of epochs to train, and loop over the epochs and batches in the train dataloader. For each batch, we get the inputs and labels, zero the gradients, forward pass the inputs through the model, compute the depth loss, backpropagate the gradients, and update the weights using the optimizer.

# %%
# Define the model and move it to the GPU
model = DepthEstimationModel()

# Define the loss function and optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 20

# Train the model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_dataloader, 0):
        # Get the inputs and labels
        inputs, labels = data
        # Move data to GPU

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = model(inputs)
        rmse = depth_loss(outputs, labels)
        loss = rmse
        loss.backward()
        optimizer.step()

        # Add current batch loss to running loss
        running_loss += loss.item()
        print(loss)
# Out:
# tensor(9.3580, grad_fn=<SqrtBackward0>)
# tensor(9.4467, grad_fn=<SqrtBackward0>)
# tensor(8.9384, grad_fn=<SqrtBackward0>)
# tensor(6.9952, grad_fn=<SqrtBackward0>)
# tensor(8.0713, grad_fn=<SqrtBackward0>)
# tensor(8.5141, grad_fn=<SqrtBackward0>)
# tensor(6.1407, grad_fn=<SqrtBackward0>)
# tensor(9.8652, grad_fn=<SqrtBackward0>)
# tensor(5.4434, grad_fn=<SqrtBackward0>)
# tensor(9.1061, grad_fn=<SqrtBackward0>)
# tensor(9.0448, grad_fn=<SqrtBackward0>)
# tensor(8.9028, grad_fn=<SqrtBackward0>)
# tensor(7.9157, grad_fn=<SqrtBackward0>)
# tensor(8.7376, grad_fn=<SqrtBackward0>)
# tensor(8.4040, grad_fn=<SqrtBackward0>)
# tensor(6.9600, grad_fn=<SqrtBackward0>)
# tensor(6.3930, grad_fn=<SqrtBackward0>)
# tensor(8.7424, grad_fn=<SqrtBackward0>)
# tensor(6.9994, grad_fn=<SqrtBackward0>)
# tensor(6.2590, grad_fn=<SqrtBackward0>)
# tensor(7.7568, grad_fn=<SqrtBackward0>)
# tensor(7.5251, grad_fn=<SqrtBackward0>)
# tensor(7.9911, grad_fn=<SqrtBackward0>)
# tensor(6.0791, grad_fn=<SqrtBackward0>)
# tensor(6.6056, grad_fn=<SqrtBackward0>)
# tensor(6.9014, grad_fn=<SqrtBackward0>)
# tensor(5.3554, grad_fn=<SqrtBackward0>)
# tensor(5.3869, grad_fn=<SqrtBackward0>)
# tensor(7.7466, grad_fn=<SqrtBackward0>)
# tensor(6.3617, grad_fn=<SqrtBackward0>)
# tensor(6.6880, grad_fn=<SqrtBackward0>)
# tensor(5.9921, grad_fn=<SqrtBackward0>)
# tensor(5.9875, grad_fn=<SqrtBackward0>)
# tensor(6.5952, grad_fn=<SqrtBackward0>)
# tensor(5.9137, grad_fn=<SqrtBackward0>)
# tensor(6.6395, grad_fn=<SqrtBackward0>)
# tensor(5.2055, grad_fn=<SqrtBackward0>)
# tensor(5.3466, grad_fn=<SqrtBackward0>)
# tensor(5.4956, grad_fn=<SqrtBackward0>)
# tensor(5.5175, grad_fn=<SqrtBackward0>)
# tensor(6.2523, grad_fn=<SqrtBackward0>)
# tensor(6.1293, grad_fn=<SqrtBackward0>)
# tensor(5.8838, grad_fn=<SqrtBackward0>)
# tensor(4.8316, grad_fn=<SqrtBackward0>)
# tensor(5.3655, grad_fn=<SqrtBackward0>)
# tensor(5.7503, grad_fn=<SqrtBackward0>)
# tensor(5.5892, grad_fn=<SqrtBackward0>)
# tensor(5.4068, grad_fn=<SqrtBackward0>)
# tensor(6.6064, grad_fn=<SqrtBackward0>)
# tensor(5.6916, grad_fn=<SqrtBackward0>)
# tensor(5.0679, grad_fn=<SqrtBackward0>)
# tensor(5.4949, grad_fn=<SqrtBackward0>)
# tensor(7.3355, grad_fn=<SqrtBackward0>)
# tensor(5.1714, grad_fn=<SqrtBackward0>)
# tensor(5.3937, grad_fn=<SqrtBackward0>)
# tensor(5.9702, grad_fn=<SqrtBackward0>)
# tensor(6.2849, grad_fn=<SqrtBackward0>)
# tensor(5.1827, grad_fn=<SqrtBackward0>)
# tensor(4.8405, grad_fn=<SqrtBackward0>)
# tensor(7.0534, grad_fn=<SqrtBackward0>)
# tensor(4.1754, grad_fn=<SqrtBackward0>)
# tensor(5.6727, grad_fn=<SqrtBackward0>)
# tensor(6.0438, grad_fn=<SqrtBackward0>)
# tensor(4.7126, grad_fn=<SqrtBackward0>)
# tensor(5.0733, grad_fn=<SqrtBackward0>)
# tensor(5.5455, grad_fn=<SqrtBackward0>)
# tensor(6.2074, grad_fn=<SqrtBackward0>)
# tensor(5.4381, grad_fn=<SqrtBackward0>)
# tensor(6.1502, grad_fn=<SqrtBackward0>)
# tensor(5.2506, grad_fn=<SqrtBackward0>)
# tensor(4.7842, grad_fn=<SqrtBackward0>)
# tensor(5.8220, grad_fn=<SqrtBackward0>)
# tensor(4.6187, grad_fn=<SqrtBackward0>)
# tensor(5.6588, grad_fn=<SqrtBackward0>)
# tensor(5.5226, grad_fn=<SqrtBackward0>)
# tensor(6.4134, grad_fn=<SqrtBackward0>)
# tensor(6.6774, grad_fn=<SqrtBackward0>)
# tensor(5.9443, grad_fn=<SqrtBackward0>)
# tensor(5.9223, grad_fn=<SqrtBackward0>)
# tensor(4.6856, grad_fn=<SqrtBackward0>)
# tensor(6.4901, grad_fn=<SqrtBackward0>)
# tensor(5.5427, grad_fn=<SqrtBackward0>)
# tensor(6.6161, grad_fn=<SqrtBackward0>)
# tensor(6.0871, grad_fn=<SqrtBackward0>)
# tensor(5.7244, grad_fn=<SqrtBackward0>)
# tensor(6.3025, grad_fn=<SqrtBackward0>)
# tensor(5.9318, grad_fn=<SqrtBackward0>)
# tensor(5.9287, grad_fn=<SqrtBackward0>)
# tensor(5.0211, grad_fn=<SqrtBackward0>)
# tensor(6.2618, grad_fn=<SqrtBackward0>)
# tensor(5.8316, grad_fn=<SqrtBackward0>)
# tensor(6.0693, grad_fn=<SqrtBackward0>)
# tensor(4.8403, grad_fn=<SqrtBackward0>)
# tensor(5.9166, grad_fn=<SqrtBackward0>)
# tensor(5.4136, grad_fn=<SqrtBackward0>)
# tensor(5.9422, grad_fn=<SqrtBackward0>)
# tensor(5.3049, grad_fn=<SqrtBackward0>)
# tensor(4.9216, grad_fn=<SqrtBackward0>)
# tensor(6.2292, grad_fn=<SqrtBackward0>)
# tensor(5.2417, grad_fn=<SqrtBackward0>)
# tensor(5.4806, grad_fn=<SqrtBackward0>)
# tensor(6.3616, grad_fn=<SqrtBackward0>)
# tensor(4.6443, grad_fn=<SqrtBackward0>)
# tensor(4.6868, grad_fn=<SqrtBackward0>)
# tensor(5.6213, grad_fn=<SqrtBackward0>)
# tensor(6.0186, grad_fn=<SqrtBackward0>)
# tensor(5.2319, grad_fn=<SqrtBackward0>)
# tensor(5.7587, grad_fn=<SqrtBackward0>)
# tensor(5.6571, grad_fn=<SqrtBackward0>)
# tensor(5.4456, grad_fn=<SqrtBackward0>)
# tensor(5.2305, grad_fn=<SqrtBackward0>)
# tensor(5.2515, grad_fn=<SqrtBackward0>)
# tensor(6.9292, grad_fn=<SqrtBackward0>)
# tensor(5.0696, grad_fn=<SqrtBackward0>)
# tensor(6.1143, grad_fn=<SqrtBackward0>)
# tensor(5.6669, grad_fn=<SqrtBackward0>)
# tensor(5.5806, grad_fn=<SqrtBackward0>)
# tensor(4.6443, grad_fn=<SqrtBackward0>)
# tensor(5.3162, grad_fn=<SqrtBackward0>)
# tensor(4.1973, grad_fn=<SqrtBackward0>)
# tensor(5.8321, grad_fn=<SqrtBackward0>)
# tensor(5.3780, grad_fn=<SqrtBackward0>)
# tensor(5.4099, grad_fn=<SqrtBackward0>)
# tensor(4.0640, grad_fn=<SqrtBackward0>)
# tensor(5.7785, grad_fn=<SqrtBackward0>)
# tensor(6.3741, grad_fn=<SqrtBackward0>)
# tensor(5.6209, grad_fn=<SqrtBackward0>)
# tensor(4.8284, grad_fn=<SqrtBackward0>)
# tensor(5.8650, grad_fn=<SqrtBackward0>)
# tensor(5.3098, grad_fn=<SqrtBackward0>)
# tensor(5.5342, grad_fn=<SqrtBackward0>)
# tensor(4.2345, grad_fn=<SqrtBackward0>)
# tensor(5.9227, grad_fn=<SqrtBackward0>)
# tensor(5.9374, grad_fn=<SqrtBackward0>)
# tensor(6.0385, grad_fn=<SqrtBackward0>)
# tensor(6.5876, grad_fn=<SqrtBackward0>)
# tensor(5.6196, grad_fn=<SqrtBackward0>)
# tensor(4.9103, grad_fn=<SqrtBackward0>)
# tensor(4.4331, grad_fn=<SqrtBackward0>)
# tensor(4.5926, grad_fn=<SqrtBackward0>)
# tensor(5.4454, grad_fn=<SqrtBackward0>)
# tensor(5.4574, grad_fn=<SqrtBackward0>)
# tensor(5.4438, grad_fn=<SqrtBackward0>)
# tensor(5.8108, grad_fn=<SqrtBackward0>)
# tensor(5.0553, grad_fn=<SqrtBackward0>)
# tensor(5.6596, grad_fn=<SqrtBackward0>)
# tensor(5.7075, grad_fn=<SqrtBackward0>)
# tensor(5.2886, grad_fn=<SqrtBackward0>)
# tensor(5.2334, grad_fn=<SqrtBackward0>)
# tensor(5.0385, grad_fn=<SqrtBackward0>)
# tensor(5.3023, grad_fn=<SqrtBackward0>)
# tensor(5.3799, grad_fn=<SqrtBackward0>)
# tensor(5.6050, grad_fn=<SqrtBackward0>)
# tensor(4.3075, grad_fn=<SqrtBackward0>)
# tensor(4.9330, grad_fn=<SqrtBackward0>)
# tensor(4.7870, grad_fn=<SqrtBackward0>)
# tensor(5.4401, grad_fn=<SqrtBackward0>)
# tensor(6.4042, grad_fn=<SqrtBackward0>)
# tensor(5.8595, grad_fn=<SqrtBackward0>)
# tensor(5.4503, grad_fn=<SqrtBackward0>)
# tensor(6.0172, grad_fn=<SqrtBackward0>)
# tensor(5.8947, grad_fn=<SqrtBackward0>)
# tensor(5.9448, grad_fn=<SqrtBackward0>)
# tensor(5.3080, grad_fn=<SqrtBackward0>)
# tensor(4.6621, grad_fn=<SqrtBackward0>)
# tensor(5.5521, grad_fn=<SqrtBackward0>)
# tensor(5.5705, grad_fn=<SqrtBackward0>)
# tensor(5.3275, grad_fn=<SqrtBackward0>)
# tensor(6.2077, grad_fn=<SqrtBackward0>)
# tensor(6.8468, grad_fn=<SqrtBackward0>)
# tensor(5.7639, grad_fn=<SqrtBackward0>)
# tensor(5.4155, grad_fn=<SqrtBackward0>)
# tensor(4.4723, grad_fn=<SqrtBackward0>)
# tensor(5.1553, grad_fn=<SqrtBackward0>)
# tensor(5.5195, grad_fn=<SqrtBackward0>)
# tensor(5.3182, grad_fn=<SqrtBackward0>)
# tensor(5.0890, grad_fn=<SqrtBackward0>)
# tensor(3.9359, grad_fn=<SqrtBackward0>)
# tensor(5.4643, grad_fn=<SqrtBackward0>)
# tensor(6.2716, grad_fn=<SqrtBackward0>)
# tensor(5.1528, grad_fn=<SqrtBackward0>)
# tensor(5.2730, grad_fn=<SqrtBackward0>)
# tensor(5.7126, grad_fn=<SqrtBackward0>)
# tensor(5.0973, grad_fn=<SqrtBackward0>)
# tensor(5.4089, grad_fn=<SqrtBackward0>)
# tensor(4.9332, grad_fn=<SqrtBackward0>)
# tensor(4.4715, grad_fn=<SqrtBackward0>)
# tensor(4.9232, grad_fn=<SqrtBackward0>)
# tensor(5.6191, grad_fn=<SqrtBackward0>)
# tensor(4.8786, grad_fn=<SqrtBackward0>)
# tensor(4.8601, grad_fn=<SqrtBackward0>)
# tensor(5.2768, grad_fn=<SqrtBackward0>)
# tensor(5.3363, grad_fn=<SqrtBackward0>)
# tensor(5.0611, grad_fn=<SqrtBackward0>)
# tensor(5.2660, grad_fn=<SqrtBackward0>)
# tensor(5.0491, grad_fn=<SqrtBackward0>)
# tensor(5.3981, grad_fn=<SqrtBackward0>)
# tensor(4.8849, grad_fn=<SqrtBackward0>)
# tensor(5.3955, grad_fn=<SqrtBackward0>)
# tensor(5.5542, grad_fn=<SqrtBackward0>)
# tensor(6.4003, grad_fn=<SqrtBackward0>)
# tensor(4.6748, grad_fn=<SqrtBackward0>)
# tensor(5.7743, grad_fn=<SqrtBackward0>)
# tensor(5.3044, grad_fn=<SqrtBackward0>)
# tensor(5.8541, grad_fn=<SqrtBackward0>)
# tensor(6.4294, grad_fn=<SqrtBackward0>)
# tensor(5.2530, grad_fn=<SqrtBackward0>)
# tensor(6.1737, grad_fn=<SqrtBackward0>)
# tensor(5.5550, grad_fn=<SqrtBackward0>)
# tensor(4.7777, grad_fn=<SqrtBackward0>)
# tensor(5.4499, grad_fn=<SqrtBackward0>)
# tensor(5.3049, grad_fn=<SqrtBackward0>)
# tensor(5.9997, grad_fn=<SqrtBackward0>)
# tensor(5.2215, grad_fn=<SqrtBackward0>)
# tensor(4.7613, grad_fn=<SqrtBackward0>)
# tensor(6.2954, grad_fn=<SqrtBackward0>)
# tensor(3.6464, grad_fn=<SqrtBackward0>)
# tensor(5.6811, grad_fn=<SqrtBackward0>)
# tensor(5.3509, grad_fn=<SqrtBackward0>)
# tensor(5.3617, grad_fn=<SqrtBackward0>)
# tensor(5.4900, grad_fn=<SqrtBackward0>)
# tensor(5.9595, grad_fn=<SqrtBackward0>)
# tensor(5.4051, grad_fn=<SqrtBackward0>)
# tensor(5.1347, grad_fn=<SqrtBackward0>)
# tensor(4.8879, grad_fn=<SqrtBackward0>)
# tensor(5.9150, grad_fn=<SqrtBackward0>)
# tensor(5.4348, grad_fn=<SqrtBackward0>)
# tensor(5.8848, grad_fn=<SqrtBackward0>)
# tensor(5.3556, grad_fn=<SqrtBackward0>)
# tensor(5.4170, grad_fn=<SqrtBackward0>)
# tensor(6.2317, grad_fn=<SqrtBackward0>)
# tensor(5.2764, grad_fn=<SqrtBackward0>)
# tensor(5.8309, grad_fn=<SqrtBackward0>)
# tensor(4.5439, grad_fn=<SqrtBackward0>)
# tensor(5.4007, grad_fn=<SqrtBackward0>)
# tensor(4.5122, grad_fn=<SqrtBackward0>)
# tensor(4.7900, grad_fn=<SqrtBackward0>)
# tensor(4.6790, grad_fn=<SqrtBackward0>)
# tensor(5.2635, grad_fn=<SqrtBackward0>)
# tensor(5.4358, grad_fn=<SqrtBackward0>)
# tensor(5.7919, grad_fn=<SqrtBackward0>)
# tensor(5.2598, grad_fn=<SqrtBackward0>)
# tensor(6.1375, grad_fn=<SqrtBackward0>)
# tensor(5.6313, grad_fn=<SqrtBackward0>)
# tensor(5.7828, grad_fn=<SqrtBackward0>)
# tensor(5.9377, grad_fn=<SqrtBackward0>)
# tensor(5.3809, grad_fn=<SqrtBackward0>)
# tensor(5.9894, grad_fn=<SqrtBackward0>)
# tensor(5.9495, grad_fn=<SqrtBackward0>)
# tensor(5.4273, grad_fn=<SqrtBackward0>)
# tensor(5.7340, grad_fn=<SqrtBackward0>)
# tensor(5.1936, grad_fn=<SqrtBackward0>)
# tensor(6.1358, grad_fn=<SqrtBackward0>)
# tensor(5.7215, grad_fn=<SqrtBackward0>)
# tensor(5.3099, grad_fn=<SqrtBackward0>)
# tensor(6.3205, grad_fn=<SqrtBackward0>)
# tensor(5.7211, grad_fn=<SqrtBackward0>)
# tensor(4.2553, grad_fn=<SqrtBackward0>)
# tensor(5.3202, grad_fn=<SqrtBackward0>)
# tensor(5.4022, grad_fn=<SqrtBackward0>)
# tensor(5.3609, grad_fn=<SqrtBackward0>)
# tensor(4.6411, grad_fn=<SqrtBackward0>)
# tensor(5.5328, grad_fn=<SqrtBackward0>)
# tensor(4.5871, grad_fn=<SqrtBackward0>)
# tensor(5.7789, grad_fn=<SqrtBackward0>)
# tensor(6.7481, grad_fn=<SqrtBackward0>)
# tensor(5.4841, grad_fn=<SqrtBackward0>)
# tensor(4.9847, grad_fn=<SqrtBackward0>)
# tensor(5.7499, grad_fn=<SqrtBackward0>)
# tensor(6.4535, grad_fn=<SqrtBackward0>)
# tensor(4.5435, grad_fn=<SqrtBackward0>)
# tensor(5.5268, grad_fn=<SqrtBackward0>)
# tensor(6.0389, grad_fn=<SqrtBackward0>)
# tensor(6.1008, grad_fn=<SqrtBackward0>)
# tensor(5.0090, grad_fn=<SqrtBackward0>)
# tensor(5.5154, grad_fn=<SqrtBackward0>)
# tensor(5.6459, grad_fn=<SqrtBackward0>)
# tensor(6.4418, grad_fn=<SqrtBackward0>)
# tensor(6.0291, grad_fn=<SqrtBackward0>)
# tensor(5.4215, grad_fn=<SqrtBackward0>)
# tensor(5.9955, grad_fn=<SqrtBackward0>)
# tensor(5.5671, grad_fn=<SqrtBackward0>)
# tensor(5.0152, grad_fn=<SqrtBackward0>)
# tensor(6.1842, grad_fn=<SqrtBackward0>)
# tensor(5.9058, grad_fn=<SqrtBackward0>)
# tensor(5.2493, grad_fn=<SqrtBackward0>)
# tensor(4.8039, grad_fn=<SqrtBackward0>)
# tensor(6.4458, grad_fn=<SqrtBackward0>)
# tensor(6.2175, grad_fn=<SqrtBackward0>)
# tensor(5.4320, grad_fn=<SqrtBackward0>)
# tensor(5.6439, grad_fn=<SqrtBackward0>)
# tensor(5.4975, grad_fn=<SqrtBackward0>)
# tensor(4.6395, grad_fn=<SqrtBackward0>)
# tensor(6.9688, grad_fn=<SqrtBackward0>)
# tensor(5.7521, grad_fn=<SqrtBackward0>)
# tensor(4.2243, grad_fn=<SqrtBackward0>)
# tensor(5.5255, grad_fn=<SqrtBackward0>)
# tensor(4.8304, grad_fn=<SqrtBackward0>)
# tensor(5.7597, grad_fn=<SqrtBackward0>)
# tensor(5.3268, grad_fn=<SqrtBackward0>)
# tensor(4.6881, grad_fn=<SqrtBackward0>)
# tensor(6.5132, grad_fn=<SqrtBackward0>)
# tensor(6.2766, grad_fn=<SqrtBackward0>)
# tensor(5.4329, grad_fn=<SqrtBackward0>)
# tensor(5.5943, grad_fn=<SqrtBackward0>)
# tensor(5.4027, grad_fn=<SqrtBackward0>)
# tensor(7.1961, grad_fn=<SqrtBackward0>)
# tensor(7.4151, grad_fn=<SqrtBackward0>)
# tensor(5.6586, grad_fn=<SqrtBackward0>)
# tensor(6.4197, grad_fn=<SqrtBackward0>)
# tensor(5.8562, grad_fn=<SqrtBackward0>)
# tensor(7.0448, grad_fn=<SqrtBackward0>)
# tensor(5.1726, grad_fn=<SqrtBackward0>)
# tensor(4.4954, grad_fn=<SqrtBackward0>)
# tensor(4.9110, grad_fn=<SqrtBackward0>)
# tensor(5.2518, grad_fn=<SqrtBackward0>)
# tensor(5.8276, grad_fn=<SqrtBackward0>)
# tensor(5.0604, grad_fn=<SqrtBackward0>)
# tensor(4.8332, grad_fn=<SqrtBackward0>)
# tensor(5.5658, grad_fn=<SqrtBackward0>)
# tensor(5.1317, grad_fn=<SqrtBackward0>)
# tensor(4.5584, grad_fn=<SqrtBackward0>)
# tensor(5.3315, grad_fn=<SqrtBackward0>)
# tensor(4.9773, grad_fn=<SqrtBackward0>)
# tensor(4.3024, grad_fn=<SqrtBackward0>)
# tensor(5.5363, grad_fn=<SqrtBackward0>)
# tensor(4.7986, grad_fn=<SqrtBackward0>)
# tensor(6.0922, grad_fn=<SqrtBackward0>)
# tensor(4.8020, grad_fn=<SqrtBackward0>)
# tensor(5.3633, grad_fn=<SqrtBackward0>)
# tensor(5.3699, grad_fn=<SqrtBackward0>)
# tensor(4.7615, grad_fn=<SqrtBackward0>)
# tensor(6.1388, grad_fn=<SqrtBackward0>)
# tensor(5.6120, grad_fn=<SqrtBackward0>)
# tensor(4.0991, grad_fn=<SqrtBackward0>)
# tensor(6.6394, grad_fn=<SqrtBackward0>)
# tensor(5.1869, grad_fn=<SqrtBackward0>)
# tensor(5.6436, grad_fn=<SqrtBackward0>)
# tensor(5.6337, grad_fn=<SqrtBackward0>)
# tensor(4.7689, grad_fn=<SqrtBackward0>)
# tensor(5.5583, grad_fn=<SqrtBackward0>)
# tensor(4.3491, grad_fn=<SqrtBackward0>)
# tensor(6.4229, grad_fn=<SqrtBackward0>)
# tensor(6.3833, grad_fn=<SqrtBackward0>)
# tensor(4.1487, grad_fn=<SqrtBackward0>)
# tensor(6.1730, grad_fn=<SqrtBackward0>)
# tensor(5.6087, grad_fn=<SqrtBackward0>)
# tensor(5.3495, grad_fn=<SqrtBackward0>)
# tensor(5.0661, grad_fn=<SqrtBackward0>)
# tensor(6.4691, grad_fn=<SqrtBackward0>)
# tensor(6.1838, grad_fn=<SqrtBackward0>)
# tensor(5.2427, grad_fn=<SqrtBackward0>)
# tensor(5.0024, grad_fn=<SqrtBackward0>)
# tensor(5.4720, grad_fn=<SqrtBackward0>)
# tensor(5.4921, grad_fn=<SqrtBackward0>)
# tensor(5.5212, grad_fn=<SqrtBackward0>)
# tensor(5.4872, grad_fn=<SqrtBackward0>)
# tensor(5.2729, grad_fn=<SqrtBackward0>)
# tensor(5.2233, grad_fn=<SqrtBackward0>)
# tensor(5.7297, grad_fn=<SqrtBackward0>)
# tensor(5.6853, grad_fn=<SqrtBackward0>)
# tensor(4.8251, grad_fn=<SqrtBackward0>)
# tensor(5.1202, grad_fn=<SqrtBackward0>)
# tensor(4.1742, grad_fn=<SqrtBackward0>)
# tensor(6.3469, grad_fn=<SqrtBackward0>)
# tensor(5.3547, grad_fn=<SqrtBackward0>)
# tensor(6.0933, grad_fn=<SqrtBackward0>)
# tensor(5.6745, grad_fn=<SqrtBackward0>)
# tensor(5.4207, grad_fn=<SqrtBackward0>)
# tensor(5.3592, grad_fn=<SqrtBackward0>)
# tensor(4.8789, grad_fn=<SqrtBackward0>)
# tensor(6.2644, grad_fn=<SqrtBackward0>)
# tensor(5.9677, grad_fn=<SqrtBackward0>)
# tensor(5.3046, grad_fn=<SqrtBackward0>)
# tensor(4.9442, grad_fn=<SqrtBackward0>)
# tensor(5.8766, grad_fn=<SqrtBackward0>)
# tensor(5.1862, grad_fn=<SqrtBackward0>)
# tensor(5.0238, grad_fn=<SqrtBackward0>)
# tensor(5.9536, grad_fn=<SqrtBackward0>)
# tensor(4.5813, grad_fn=<SqrtBackward0>)
# tensor(4.5190, grad_fn=<SqrtBackward0>)
# tensor(4.9927, grad_fn=<SqrtBackward0>)
# tensor(5.8497, grad_fn=<SqrtBackward0>)
# tensor(4.5359, grad_fn=<SqrtBackward0>)
# tensor(4.0236, grad_fn=<SqrtBackward0>)
# tensor(4.6816, grad_fn=<SqrtBackward0>)
# tensor(4.6107, grad_fn=<SqrtBackward0>)
# tensor(4.9138, grad_fn=<SqrtBackward0>)
# tensor(5.2665, grad_fn=<SqrtBackward0>)
# tensor(5.2056, grad_fn=<SqrtBackward0>)
# tensor(5.8936, grad_fn=<SqrtBackward0>)
# tensor(6.1524, grad_fn=<SqrtBackward0>)
# tensor(5.3261, grad_fn=<SqrtBackward0>)
# tensor(5.4199, grad_fn=<SqrtBackward0>)
# tensor(4.8477, grad_fn=<SqrtBackward0>)
# tensor(6.2572, grad_fn=<SqrtBackward0>)
# tensor(4.9170, grad_fn=<SqrtBackward0>)
# tensor(5.8664, grad_fn=<SqrtBackward0>)
# tensor(5.1842, grad_fn=<SqrtBackward0>)
# tensor(5.0229, grad_fn=<SqrtBackward0>)
# tensor(5.0481, grad_fn=<SqrtBackward0>)
# tensor(4.9076, grad_fn=<SqrtBackward0>)
# tensor(6.1698, grad_fn=<SqrtBackward0>)
# tensor(6.5148, grad_fn=<SqrtBackward0>)
# tensor(6.1948, grad_fn=<SqrtBackward0>)
# tensor(4.2150, grad_fn=<SqrtBackward0>)
# tensor(6.3622, grad_fn=<SqrtBackward0>)
# tensor(5.4871, grad_fn=<SqrtBackward0>)
# tensor(4.8530, grad_fn=<SqrtBackward0>)
# tensor(5.7383, grad_fn=<SqrtBackward0>)
# tensor(4.6838, grad_fn=<SqrtBackward0>)
# tensor(5.8031, grad_fn=<SqrtBackward0>)
# tensor(6.4692, grad_fn=<SqrtBackward0>)
# tensor(5.4973, grad_fn=<SqrtBackward0>)
# tensor(4.5741, grad_fn=<SqrtBackward0>)
# tensor(4.7648, grad_fn=<SqrtBackward0>)
# tensor(5.2440, grad_fn=<SqrtBackward0>)
# tensor(4.6790, grad_fn=<SqrtBackward0>)
# tensor(6.6104, grad_fn=<SqrtBackward0>)
# tensor(5.2147, grad_fn=<SqrtBackward0>)
# tensor(5.9783, grad_fn=<SqrtBackward0>)
# tensor(5.9798, grad_fn=<SqrtBackward0>)
# tensor(5.4641, grad_fn=<SqrtBackward0>)
# tensor(6.2146, grad_fn=<SqrtBackward0>)
# tensor(5.0622, grad_fn=<SqrtBackward0>)
# tensor(5.3610, grad_fn=<SqrtBackward0>)
# tensor(5.9493, grad_fn=<SqrtBackward0>)
# tensor(4.6548, grad_fn=<SqrtBackward0>)
# tensor(5.3952, grad_fn=<SqrtBackward0>)
# tensor(5.0478, grad_fn=<SqrtBackward0>)
# tensor(5.9110, grad_fn=<SqrtBackward0>)
# tensor(5.3754, grad_fn=<SqrtBackward0>)
# tensor(5.2747, grad_fn=<SqrtBackward0>)
# tensor(5.5368, grad_fn=<SqrtBackward0>)
# tensor(4.8165, grad_fn=<SqrtBackward0>)
# tensor(5.7591, grad_fn=<SqrtBackward0>)
# tensor(5.7144, grad_fn=<SqrtBackward0>)
# tensor(5.2279, grad_fn=<SqrtBackward0>)
# tensor(5.5807, grad_fn=<SqrtBackward0>)
# tensor(5.2036, grad_fn=<SqrtBackward0>)
# tensor(6.3760, grad_fn=<SqrtBackward0>)
# tensor(5.7284, grad_fn=<SqrtBackward0>)
# tensor(6.6085, grad_fn=<SqrtBackward0>)
# tensor(4.7388, grad_fn=<SqrtBackward0>)
# tensor(5.2105, grad_fn=<SqrtBackward0>)
# tensor(4.6949, grad_fn=<SqrtBackward0>)
# tensor(4.8934, grad_fn=<SqrtBackward0>)
# tensor(5.1726, grad_fn=<SqrtBackward0>)
# tensor(4.9950, grad_fn=<SqrtBackward0>)
# tensor(4.9163, grad_fn=<SqrtBackward0>)
# tensor(5.6027, grad_fn=<SqrtBackward0>)
# tensor(5.4932, grad_fn=<SqrtBackward0>)
# tensor(5.4584, grad_fn=<SqrtBackward0>)
# tensor(5.1143, grad_fn=<SqrtBackward0>)
# tensor(5.3972, grad_fn=<SqrtBackward0>)
# tensor(4.8691, grad_fn=<SqrtBackward0>)
# tensor(4.9266, grad_fn=<SqrtBackward0>)
# tensor(5.2903, grad_fn=<SqrtBackward0>)
# tensor(5.4066, grad_fn=<SqrtBackward0>)
# tensor(5.4029, grad_fn=<SqrtBackward0>)
# tensor(6.2173, grad_fn=<SqrtBackward0>)
# tensor(5.3528, grad_fn=<SqrtBackward0>)
# tensor(5.6798, grad_fn=<SqrtBackward0>)
# tensor(6.0993, grad_fn=<SqrtBackward0>)
# tensor(5.5240, grad_fn=<SqrtBackward0>)
# tensor(4.9210, grad_fn=<SqrtBackward0>)
# tensor(4.8104, grad_fn=<SqrtBackward0>)
# tensor(5.4104, grad_fn=<SqrtBackward0>)
# tensor(4.5869, grad_fn=<SqrtBackward0>)
# tensor(4.7312, grad_fn=<SqrtBackward0>)
# tensor(4.8237, grad_fn=<SqrtBackward0>)
# tensor(5.2087, grad_fn=<SqrtBackward0>)
# tensor(5.5235, grad_fn=<SqrtBackward0>)
# tensor(5.4023, grad_fn=<SqrtBackward0>)
# tensor(5.3574, grad_fn=<SqrtBackward0>)
# tensor(5.4909, grad_fn=<SqrtBackward0>)
# tensor(4.9046, grad_fn=<SqrtBackward0>)
# tensor(5.3869, grad_fn=<SqrtBackward0>)
# tensor(4.8129, grad_fn=<SqrtBackward0>)
# tensor(5.5662, grad_fn=<SqrtBackward0>)
# tensor(4.7726, grad_fn=<SqrtBackward0>)
# tensor(5.4543, grad_fn=<SqrtBackward0>)
# tensor(5.1071, grad_fn=<SqrtBackward0>)
# tensor(4.2516, grad_fn=<SqrtBackward0>)
# tensor(4.6501, grad_fn=<SqrtBackward0>)
# tensor(5.2867, grad_fn=<SqrtBackward0>)
# tensor(5.5324, grad_fn=<SqrtBackward0>)
# tensor(5.2807, grad_fn=<SqrtBackward0>)
# tensor(6.0083, grad_fn=<SqrtBackward0>)
# tensor(5.5153, grad_fn=<SqrtBackward0>)
# tensor(4.8340, grad_fn=<SqrtBackward0>)
# tensor(4.9625, grad_fn=<SqrtBackward0>)
# tensor(6.6348, grad_fn=<SqrtBackward0>)
# tensor(5.7625, grad_fn=<SqrtBackward0>)
# tensor(5.6729, grad_fn=<SqrtBackward0>)
# tensor(4.2570, grad_fn=<SqrtBackward0>)
# tensor(5.0432, grad_fn=<SqrtBackward0>)
# tensor(5.9980, grad_fn=<SqrtBackward0>)
# tensor(5.1348, grad_fn=<SqrtBackward0>)
# tensor(5.0956, grad_fn=<SqrtBackward0>)
# tensor(6.1985, grad_fn=<SqrtBackward0>)
# tensor(6.2801, grad_fn=<SqrtBackward0>)
# tensor(5.8598, grad_fn=<SqrtBackward0>)
# tensor(5.2699, grad_fn=<SqrtBackward0>)
# tensor(5.2061, grad_fn=<SqrtBackward0>)
# tensor(6.0516, grad_fn=<SqrtBackward0>)
# tensor(6.1142, grad_fn=<SqrtBackward0>)
# tensor(4.6864, grad_fn=<SqrtBackward0>)
# tensor(5.1015, grad_fn=<SqrtBackward0>)
# tensor(6.0420, grad_fn=<SqrtBackward0>)
# tensor(4.9235, grad_fn=<SqrtBackward0>)
# tensor(4.7944, grad_fn=<SqrtBackward0>)
# tensor(5.9462, grad_fn=<SqrtBackward0>)
# tensor(5.0279, grad_fn=<SqrtBackward0>)
# tensor(5.8511, grad_fn=<SqrtBackward0>)
# tensor(4.0518, grad_fn=<SqrtBackward0>)
# tensor(5.2019, grad_fn=<SqrtBackward0>)
# tensor(5.5859, grad_fn=<SqrtBackward0>)
# tensor(4.5846, grad_fn=<SqrtBackward0>)
# tensor(6.1523, grad_fn=<SqrtBackward0>)
# tensor(5.3412, grad_fn=<SqrtBackward0>)
# tensor(5.3131, grad_fn=<SqrtBackward0>)
# tensor(5.4784, grad_fn=<SqrtBackward0>)
# tensor(5.7102, grad_fn=<SqrtBackward0>)
# tensor(6.1424, grad_fn=<SqrtBackward0>)
# tensor(5.0212, grad_fn=<SqrtBackward0>)
# tensor(5.3400, grad_fn=<SqrtBackward0>)
# tensor(5.6460, grad_fn=<SqrtBackward0>)
# tensor(5.3885, grad_fn=<SqrtBackward0>)
# tensor(5.6741, grad_fn=<SqrtBackward0>)
# tensor(4.7283, grad_fn=<SqrtBackward0>)
# tensor(5.2991, grad_fn=<SqrtBackward0>)
# tensor(5.1521, grad_fn=<SqrtBackward0>)
# tensor(5.6344, grad_fn=<SqrtBackward0>)
# tensor(4.9501, grad_fn=<SqrtBackward0>)
# tensor(6.3073, grad_fn=<SqrtBackward0>)
# tensor(6.5575, grad_fn=<SqrtBackward0>)
# tensor(5.4170, grad_fn=<SqrtBackward0>)
# tensor(5.2018, grad_fn=<SqrtBackward0>)
# tensor(6.1638, grad_fn=<SqrtBackward0>)
# tensor(6.0948, grad_fn=<SqrtBackward0>)
# tensor(5.4694, grad_fn=<SqrtBackward0>)
# tensor(6.1585, grad_fn=<SqrtBackward0>)
# tensor(5.6123, grad_fn=<SqrtBackward0>)
# tensor(5.5785, grad_fn=<SqrtBackward0>)
# tensor(5.3156, grad_fn=<SqrtBackward0>)
# tensor(5.1135, grad_fn=<SqrtBackward0>)
# tensor(5.3780, grad_fn=<SqrtBackward0>)
# tensor(4.9146, grad_fn=<SqrtBackward0>)
# tensor(4.6789, grad_fn=<SqrtBackward0>)
# tensor(4.9236, grad_fn=<SqrtBackward0>)
# tensor(5.4507, grad_fn=<SqrtBackward0>)
# tensor(5.8419, grad_fn=<SqrtBackward0>)
# tensor(5.0067, grad_fn=<SqrtBackward0>)
# tensor(5.4673, grad_fn=<SqrtBackward0>)
# tensor(5.3282, grad_fn=<SqrtBackward0>)
# tensor(5.9124, grad_fn=<SqrtBackward0>)
# tensor(5.3541, grad_fn=<SqrtBackward0>)
# tensor(4.9668, grad_fn=<SqrtBackward0>)
# tensor(4.7345, grad_fn=<SqrtBackward0>)
# tensor(5.2769, grad_fn=<SqrtBackward0>)
# tensor(4.3370, grad_fn=<SqrtBackward0>)
# tensor(5.0398, grad_fn=<SqrtBackward0>)
# tensor(6.1646, grad_fn=<SqrtBackward0>)
# tensor(4.9847, grad_fn=<SqrtBackward0>)
# tensor(4.3426, grad_fn=<SqrtBackward0>)
# tensor(5.4255, grad_fn=<SqrtBackward0>)
# tensor(5.0404, grad_fn=<SqrtBackward0>)
# tensor(5.3575, grad_fn=<SqrtBackward0>)
# tensor(4.2974, grad_fn=<SqrtBackward0>)
# tensor(5.2911, grad_fn=<SqrtBackward0>)
# tensor(5.3533, grad_fn=<SqrtBackward0>)
# tensor(5.5065, grad_fn=<SqrtBackward0>)
# tensor(5.0843, grad_fn=<SqrtBackward0>)
# tensor(5.5884, grad_fn=<SqrtBackward0>)
# tensor(4.5292, grad_fn=<SqrtBackward0>)
# tensor(5.9005, grad_fn=<SqrtBackward0>)
# tensor(5.1572, grad_fn=<SqrtBackward0>)
# tensor(5.0687, grad_fn=<SqrtBackward0>)
# tensor(6.1248, grad_fn=<SqrtBackward0>)
# tensor(4.8657, grad_fn=<SqrtBackward0>)
# tensor(5.6645, grad_fn=<SqrtBackward0>)
# tensor(5.9333, grad_fn=<SqrtBackward0>)
# tensor(6.0932, grad_fn=<SqrtBackward0>)
# tensor(5.0932, grad_fn=<SqrtBackward0>)
# tensor(4.6289, grad_fn=<SqrtBackward0>)
# tensor(6.7511, grad_fn=<SqrtBackward0>)
# tensor(5.6774, grad_fn=<SqrtBackward0>)
# tensor(5.0660, grad_fn=<SqrtBackward0>)
# tensor(5.0143, grad_fn=<SqrtBackward0>)
# tensor(5.3929, grad_fn=<SqrtBackward0>)
# tensor(5.3309, grad_fn=<SqrtBackward0>)
# tensor(4.8034, grad_fn=<SqrtBackward0>)
# tensor(5.1960, grad_fn=<SqrtBackward0>)
# tensor(5.5545, grad_fn=<SqrtBackward0>)
# tensor(4.8023, grad_fn=<SqrtBackward0>)
# tensor(5.1534, grad_fn=<SqrtBackward0>)
# tensor(4.6573, grad_fn=<SqrtBackward0>)
# tensor(5.3400, grad_fn=<SqrtBackward0>)
# tensor(5.4512, grad_fn=<SqrtBackward0>)
# tensor(4.9279, grad_fn=<SqrtBackward0>)
# tensor(5.2693, grad_fn=<SqrtBackward0>)
# tensor(6.0655, grad_fn=<SqrtBackward0>)
# tensor(4.9530, grad_fn=<SqrtBackward0>)
# tensor(5.8055, grad_fn=<SqrtBackward0>)
# tensor(5.0999, grad_fn=<SqrtBackward0>)
# tensor(5.5137, grad_fn=<SqrtBackward0>)
# tensor(5.1890, grad_fn=<SqrtBackward0>)
# tensor(6.1385, grad_fn=<SqrtBackward0>)
# tensor(6.1979, grad_fn=<SqrtBackward0>)
# tensor(5.3122, grad_fn=<SqrtBackward0>)
# tensor(4.8883, grad_fn=<SqrtBackward0>)
# tensor(5.2073, grad_fn=<SqrtBackward0>)
# tensor(5.6869, grad_fn=<SqrtBackward0>)
# tensor(5.2209, grad_fn=<SqrtBackward0>)
# tensor(4.7149, grad_fn=<SqrtBackward0>)
# tensor(4.1506, grad_fn=<SqrtBackward0>)
# tensor(7.7292, grad_fn=<SqrtBackward0>)
# tensor(5.8892, grad_fn=<SqrtBackward0>)
# tensor(5.7962, grad_fn=<SqrtBackward0>)
# tensor(5.8716, grad_fn=<SqrtBackward0>)
# tensor(5.1450, grad_fn=<SqrtBackward0>)
# tensor(6.1974, grad_fn=<SqrtBackward0>)
# tensor(4.5012, grad_fn=<SqrtBackward0>)
# tensor(5.8167, grad_fn=<SqrtBackward0>)
# tensor(6.3064, grad_fn=<SqrtBackward0>)
# tensor(4.0723, grad_fn=<SqrtBackward0>)
# tensor(5.1811, grad_fn=<SqrtBackward0>)
# tensor(4.5479, grad_fn=<SqrtBackward0>)
# tensor(5.8741, grad_fn=<SqrtBackward0>)
# tensor(5.7091, grad_fn=<SqrtBackward0>)
# tensor(5.6828, grad_fn=<SqrtBackward0>)
# tensor(6.1135, grad_fn=<SqrtBackward0>)
# tensor(4.3945, grad_fn=<SqrtBackward0>)
# tensor(4.8482, grad_fn=<SqrtBackward0>)
# tensor(4.8909, grad_fn=<SqrtBackward0>)
# tensor(5.0937, grad_fn=<SqrtBackward0>)
# tensor(7.1054, grad_fn=<SqrtBackward0>)
# tensor(6.6172, grad_fn=<SqrtBackward0>)
# tensor(6.5904, grad_fn=<SqrtBackward0>)
# tensor(4.8417, grad_fn=<SqrtBackward0>)
# tensor(5.0723, grad_fn=<SqrtBackward0>)
# tensor(5.7352, grad_fn=<SqrtBackward0>)
# tensor(4.9036, grad_fn=<SqrtBackward0>)
# tensor(5.1703, grad_fn=<SqrtBackward0>)
# tensor(4.3590, grad_fn=<SqrtBackward0>)
# tensor(5.6210, grad_fn=<SqrtBackward0>)
# tensor(5.7127, grad_fn=<SqrtBackward0>)
# tensor(5.4580, grad_fn=<SqrtBackward0>)
# tensor(4.5982, grad_fn=<SqrtBackward0>)
# tensor(5.9728, grad_fn=<SqrtBackward0>)
# tensor(5.2543, grad_fn=<SqrtBackward0>)
# tensor(5.1768, grad_fn=<SqrtBackward0>)
# tensor(5.3637, grad_fn=<SqrtBackward0>)
# tensor(5.2698, grad_fn=<SqrtBackward0>)
# tensor(4.9105, grad_fn=<SqrtBackward0>)
# tensor(4.8520, grad_fn=<SqrtBackward0>)
# tensor(4.6266, grad_fn=<SqrtBackward0>)
# tensor(4.4095, grad_fn=<SqrtBackward0>)
# tensor(5.1358, grad_fn=<SqrtBackward0>)
# tensor(5.3906, grad_fn=<SqrtBackward0>)
# tensor(5.7709, grad_fn=<SqrtBackward0>)
# tensor(5.0037, grad_fn=<SqrtBackward0>)
# tensor(4.9483, grad_fn=<SqrtBackward0>)
# tensor(5.4899, grad_fn=<SqrtBackward0>)
# tensor(5.1732, grad_fn=<SqrtBackward0>)
# tensor(4.6384, grad_fn=<SqrtBackward0>)
# tensor(5.3494, grad_fn=<SqrtBackward0>)
# tensor(4.4368, grad_fn=<SqrtBackward0>)
# tensor(5.3869, grad_fn=<SqrtBackward0>)
# tensor(4.8212, grad_fn=<SqrtBackward0>)
# tensor(6.1021, grad_fn=<SqrtBackward0>)
# tensor(4.3569, grad_fn=<SqrtBackward0>)
# tensor(4.5867, grad_fn=<SqrtBackward0>)
# tensor(4.3294, grad_fn=<SqrtBackward0>)
# tensor(5.7825, grad_fn=<SqrtBackward0>)
# tensor(5.3446, grad_fn=<SqrtBackward0>)
# tensor(5.3250, grad_fn=<SqrtBackward0>)
# tensor(5.1326, grad_fn=<SqrtBackward0>)
# tensor(5.1191, grad_fn=<SqrtBackward0>)
# tensor(5.3036, grad_fn=<SqrtBackward0>)
# tensor(5.8008, grad_fn=<SqrtBackward0>)
# tensor(4.1386, grad_fn=<SqrtBackward0>)
# tensor(5.8576, grad_fn=<SqrtBackward0>)
# tensor(4.8535, grad_fn=<SqrtBackward0>)
# tensor(5.3198, grad_fn=<SqrtBackward0>)
# tensor(5.5595, grad_fn=<SqrtBackward0>)
# tensor(3.6669, grad_fn=<SqrtBackward0>)
# tensor(4.0753, grad_fn=<SqrtBackward0>)
# tensor(5.1342, grad_fn=<SqrtBackward0>)
# tensor(5.7438, grad_fn=<SqrtBackward0>)
# tensor(6.0673, grad_fn=<SqrtBackward0>)
# tensor(5.7884, grad_fn=<SqrtBackward0>)
# tensor(6.3870, grad_fn=<SqrtBackward0>)
# tensor(5.0122, grad_fn=<SqrtBackward0>)
# tensor(5.7417, grad_fn=<SqrtBackward0>)
# tensor(5.3687, grad_fn=<SqrtBackward0>)
# tensor(5.8266, grad_fn=<SqrtBackward0>)
# tensor(4.4100, grad_fn=<SqrtBackward0>)
# tensor(6.2256, grad_fn=<SqrtBackward0>)
# tensor(6.4499, grad_fn=<SqrtBackward0>)
# tensor(5.4387, grad_fn=<SqrtBackward0>)
# tensor(5.1562, grad_fn=<SqrtBackward0>)
# tensor(5.2595, grad_fn=<SqrtBackward0>)
# tensor(4.8454, grad_fn=<SqrtBackward0>)
# tensor(5.4888, grad_fn=<SqrtBackward0>)
# tensor(4.2929, grad_fn=<SqrtBackward0>)
# tensor(5.9187, grad_fn=<SqrtBackward0>)
# tensor(5.9757, grad_fn=<SqrtBackward0>)
# tensor(5.1274, grad_fn=<SqrtBackward0>)
# tensor(6.6063, grad_fn=<SqrtBackward0>)
# tensor(4.6814, grad_fn=<SqrtBackward0>)
# tensor(4.9025, grad_fn=<SqrtBackward0>)
# tensor(4.2253, grad_fn=<SqrtBackward0>)
# tensor(6.0460, grad_fn=<SqrtBackward0>)
# tensor(5.2333, grad_fn=<SqrtBackward0>)
# tensor(4.8616, grad_fn=<SqrtBackward0>)
# tensor(4.5784, grad_fn=<SqrtBackward0>)
# tensor(5.1603, grad_fn=<SqrtBackward0>)
# tensor(5.0217, grad_fn=<SqrtBackward0>)
# tensor(5.1750, grad_fn=<SqrtBackward0>)
# tensor(4.8211, grad_fn=<SqrtBackward0>)
# tensor(5.7827, grad_fn=<SqrtBackward0>)
# tensor(5.7469, grad_fn=<SqrtBackward0>)
# tensor(5.3049, grad_fn=<SqrtBackward0>)
# tensor(5.4800, grad_fn=<SqrtBackward0>)
# tensor(4.9584, grad_fn=<SqrtBackward0>)
# tensor(5.0723, grad_fn=<SqrtBackward0>)
# tensor(5.0532, grad_fn=<SqrtBackward0>)
# tensor(5.5935, grad_fn=<SqrtBackward0>)
# tensor(5.1078, grad_fn=<SqrtBackward0>)
# tensor(5.2254, grad_fn=<SqrtBackward0>)
# tensor(5.4857, grad_fn=<SqrtBackward0>)
# tensor(5.4704, grad_fn=<SqrtBackward0>)
# tensor(3.8136, grad_fn=<SqrtBackward0>)
# tensor(4.1716, grad_fn=<SqrtBackward0>)
# tensor(5.0062, grad_fn=<SqrtBackward0>)
# tensor(4.8515, grad_fn=<SqrtBackward0>)
# tensor(4.5894, grad_fn=<SqrtBackward0>)
# tensor(5.8873, grad_fn=<SqrtBackward0>)
# tensor(4.5661, grad_fn=<SqrtBackward0>)
# tensor(5.0641, grad_fn=<SqrtBackward0>)
# tensor(5.3570, grad_fn=<SqrtBackward0>)
# tensor(5.2047, grad_fn=<SqrtBackward0>)
# tensor(5.5305, grad_fn=<SqrtBackward0>)
# tensor(5.2139, grad_fn=<SqrtBackward0>)
# tensor(5.9035, grad_fn=<SqrtBackward0>)
# tensor(5.5275, grad_fn=<SqrtBackward0>)
# tensor(5.5949, grad_fn=<SqrtBackward0>)
# tensor(5.7521, grad_fn=<SqrtBackward0>)
# tensor(4.2780, grad_fn=<SqrtBackward0>)
# tensor(4.8332, grad_fn=<SqrtBackward0>)
# tensor(6.0893, grad_fn=<SqrtBackward0>)
# tensor(5.6765, grad_fn=<SqrtBackward0>)
# tensor(4.1336, grad_fn=<SqrtBackward0>)
# tensor(4.3526, grad_fn=<SqrtBackward0>)
# tensor(4.0776, grad_fn=<SqrtBackward0>)
# tensor(5.3880, grad_fn=<SqrtBackward0>)
# tensor(4.5500, grad_fn=<SqrtBackward0>)
# tensor(5.4190, grad_fn=<SqrtBackward0>)
# tensor(5.5930, grad_fn=<SqrtBackward0>)
# tensor(5.6325, grad_fn=<SqrtBackward0>)
# tensor(5.6560, grad_fn=<SqrtBackward0>)
# tensor(5.8204, grad_fn=<SqrtBackward0>)
# tensor(6.1086, grad_fn=<SqrtBackward0>)
# tensor(4.6693, grad_fn=<SqrtBackward0>)
# tensor(5.0593, grad_fn=<SqrtBackward0>)
# tensor(5.8373, grad_fn=<SqrtBackward0>)
# tensor(5.4237, grad_fn=<SqrtBackward0>)
# tensor(5.5688, grad_fn=<SqrtBackward0>)
# tensor(5.9496, grad_fn=<SqrtBackward0>)
# tensor(5.3581, grad_fn=<SqrtBackward0>)
# tensor(5.3028, grad_fn=<SqrtBackward0>)
# tensor(5.3577, grad_fn=<SqrtBackward0>)
# tensor(5.3620, grad_fn=<SqrtBackward0>)
# tensor(5.3435, grad_fn=<SqrtBackward0>)
# tensor(4.4291, grad_fn=<SqrtBackward0>)
# tensor(5.7862, grad_fn=<SqrtBackward0>)
# tensor(5.7110, grad_fn=<SqrtBackward0>)
# tensor(5.5682, grad_fn=<SqrtBackward0>)
# tensor(4.6484, grad_fn=<SqrtBackward0>)
# tensor(4.1119, grad_fn=<SqrtBackward0>)
# tensor(5.0167, grad_fn=<SqrtBackward0>)
# tensor(5.2009, grad_fn=<SqrtBackward0>)
# tensor(6.0676, grad_fn=<SqrtBackward0>)
# tensor(5.0696, grad_fn=<SqrtBackward0>)
# tensor(4.9285, grad_fn=<SqrtBackward0>)
# tensor(4.7719, grad_fn=<SqrtBackward0>)
# tensor(5.2154, grad_fn=<SqrtBackward0>)
# tensor(4.8270, grad_fn=<SqrtBackward0>)
# tensor(5.4256, grad_fn=<SqrtBackward0>)
# tensor(5.5167, grad_fn=<SqrtBackward0>)
# tensor(5.7498, grad_fn=<SqrtBackward0>)
# tensor(5.4456, grad_fn=<SqrtBackward0>)
# tensor(5.1505, grad_fn=<SqrtBackward0>)
# tensor(5.3122, grad_fn=<SqrtBackward0>)
# tensor(5.0277, grad_fn=<SqrtBackward0>)
# tensor(5.2028, grad_fn=<SqrtBackward0>)
# tensor(5.1075, grad_fn=<SqrtBackward0>)
# tensor(5.0805, grad_fn=<SqrtBackward0>)
# tensor(4.9196, grad_fn=<SqrtBackward0>)
# tensor(5.3815, grad_fn=<SqrtBackward0>)
# tensor(3.8091, grad_fn=<SqrtBackward0>)
# tensor(6.2798, grad_fn=<SqrtBackward0>)
# tensor(4.9669, grad_fn=<SqrtBackward0>)
# tensor(4.7695, grad_fn=<SqrtBackward0>)
# tensor(5.0267, grad_fn=<SqrtBackward0>)
# tensor(5.9162, grad_fn=<SqrtBackward0>)
# tensor(5.5048, grad_fn=<SqrtBackward0>)
# tensor(4.8262, grad_fn=<SqrtBackward0>)
# tensor(4.6819, grad_fn=<SqrtBackward0>)
# tensor(5.2697, grad_fn=<SqrtBackward0>)
# tensor(6.0745, grad_fn=<SqrtBackward0>)
# tensor(5.0117, grad_fn=<SqrtBackward0>)
# tensor(4.7504, grad_fn=<SqrtBackward0>)
# tensor(4.1561, grad_fn=<SqrtBackward0>)
# tensor(5.0208, grad_fn=<SqrtBackward0>)
# tensor(5.7788, grad_fn=<SqrtBackward0>)
# tensor(7.1330, grad_fn=<SqrtBackward0>)
# tensor(4.7617, grad_fn=<SqrtBackward0>)
# tensor(5.6259, grad_fn=<SqrtBackward0>)
# tensor(5.6758, grad_fn=<SqrtBackward0>)
# tensor(5.3923, grad_fn=<SqrtBackward0>)
# tensor(4.7600, grad_fn=<SqrtBackward0>)
# tensor(5.0701, grad_fn=<SqrtBackward0>)
# tensor(6.0041, grad_fn=<SqrtBackward0>)
# tensor(5.8826, grad_fn=<SqrtBackward0>)
# tensor(5.5587, grad_fn=<SqrtBackward0>)
# tensor(5.4380, grad_fn=<SqrtBackward0>)
# tensor(4.9674, grad_fn=<SqrtBackward0>)
# tensor(4.9334, grad_fn=<SqrtBackward0>)
# tensor(6.1720, grad_fn=<SqrtBackward0>)
# tensor(5.6003, grad_fn=<SqrtBackward0>)
# tensor(5.8643, grad_fn=<SqrtBackward0>)
# tensor(5.0963, grad_fn=<SqrtBackward0>)
# tensor(4.8199, grad_fn=<SqrtBackward0>)
# tensor(5.6450, grad_fn=<SqrtBackward0>)
# tensor(4.8617, grad_fn=<SqrtBackward0>)
# tensor(5.0327, grad_fn=<SqrtBackward0>)
# tensor(5.2712, grad_fn=<SqrtBackward0>)
# tensor(5.1273, grad_fn=<SqrtBackward0>)
# tensor(5.8653, grad_fn=<SqrtBackward0>)
# tensor(5.9319, grad_fn=<SqrtBackward0>)
# tensor(5.7482, grad_fn=<SqrtBackward0>)
# tensor(5.4312, grad_fn=<SqrtBackward0>)
# tensor(5.3599, grad_fn=<SqrtBackward0>)
# tensor(5.9811, grad_fn=<SqrtBackward0>)
# tensor(6.0397, grad_fn=<SqrtBackward0>)
# tensor(5.0639, grad_fn=<SqrtBackward0>)
# tensor(5.5931, grad_fn=<SqrtBackward0>)
# tensor(4.7049, grad_fn=<SqrtBackward0>)
# tensor(4.8339, grad_fn=<SqrtBackward0>)
# tensor(4.9352, grad_fn=<SqrtBackward0>)
# tensor(5.2138, grad_fn=<SqrtBackward0>)
# tensor(4.4448, grad_fn=<SqrtBackward0>)
# tensor(4.4516, grad_fn=<SqrtBackward0>)
# tensor(5.4549, grad_fn=<SqrtBackward0>)
# tensor(5.4074, grad_fn=<SqrtBackward0>)
# tensor(5.8722, grad_fn=<SqrtBackward0>)
# tensor(4.7106, grad_fn=<SqrtBackward0>)
# tensor(6.0327, grad_fn=<SqrtBackward0>)
# tensor(4.0099, grad_fn=<SqrtBackward0>)
# tensor(6.5576, grad_fn=<SqrtBackward0>)
# tensor(7.0086, grad_fn=<SqrtBackward0>)
# tensor(6.4915, grad_fn=<SqrtBackward0>)
# tensor(4.0690, grad_fn=<SqrtBackward0>)
# tensor(5.4852, grad_fn=<SqrtBackward0>)
# tensor(4.9591, grad_fn=<SqrtBackward0>)
# tensor(5.0310, grad_fn=<SqrtBackward0>)
# tensor(5.8605, grad_fn=<SqrtBackward0>)
# tensor(4.6535, grad_fn=<SqrtBackward0>)
# tensor(5.0258, grad_fn=<SqrtBackward0>)
# tensor(6.2709, grad_fn=<SqrtBackward0>)
# tensor(5.9677, grad_fn=<SqrtBackward0>)
# tensor(5.3172, grad_fn=<SqrtBackward0>)
# tensor(5.1767, grad_fn=<SqrtBackward0>)
# tensor(5.2111, grad_fn=<SqrtBackward0>)
# tensor(6.2755, grad_fn=<SqrtBackward0>)
# tensor(5.7650, grad_fn=<SqrtBackward0>)
# tensor(4.5186, grad_fn=<SqrtBackward0>)
# tensor(5.3129, grad_fn=<SqrtBackward0>)
# tensor(4.4097, grad_fn=<SqrtBackward0>)
# tensor(5.5771, grad_fn=<SqrtBackward0>)
# tensor(5.9359, grad_fn=<SqrtBackward0>)
# tensor(5.3462, grad_fn=<SqrtBackward0>)
# tensor(5.1401, grad_fn=<SqrtBackward0>)
# tensor(6.0229, grad_fn=<SqrtBackward0>)
# tensor(4.9549, grad_fn=<SqrtBackward0>)
# tensor(4.5099, grad_fn=<SqrtBackward0>)
# tensor(5.9235, grad_fn=<SqrtBackward0>)
# tensor(5.4639, grad_fn=<SqrtBackward0>)
# tensor(5.2246, grad_fn=<SqrtBackward0>)
# tensor(5.3060, grad_fn=<SqrtBackward0>)
# tensor(5.6385, grad_fn=<SqrtBackward0>)
# tensor(5.6104, grad_fn=<SqrtBackward0>)
# tensor(5.8279, grad_fn=<SqrtBackward0>)
# tensor(4.9302, grad_fn=<SqrtBackward0>)
# tensor(5.1081, grad_fn=<SqrtBackward0>)
# tensor(5.6468, grad_fn=<SqrtBackward0>)
# tensor(6.1385, grad_fn=<SqrtBackward0>)
# tensor(4.0673, grad_fn=<SqrtBackward0>)
# tensor(4.3142, grad_fn=<SqrtBackward0>)
# tensor(5.7256, grad_fn=<SqrtBackward0>)
# tensor(4.6386, grad_fn=<SqrtBackward0>)
# tensor(4.6055, grad_fn=<SqrtBackward0>)
# tensor(4.7847, grad_fn=<SqrtBackward0>)
# tensor(5.8433, grad_fn=<SqrtBackward0>)
# tensor(4.9558, grad_fn=<SqrtBackward0>)
# tensor(4.6619, grad_fn=<SqrtBackward0>)
# tensor(4.8129, grad_fn=<SqrtBackward0>)
# tensor(5.6523, grad_fn=<SqrtBackward0>)
# tensor(5.6263, grad_fn=<SqrtBackward0>)
# tensor(5.3393, grad_fn=<SqrtBackward0>)
# tensor(4.5155, grad_fn=<SqrtBackward0>)
# tensor(6.2535, grad_fn=<SqrtBackward0>)
# tensor(4.8146, grad_fn=<SqrtBackward0>)
# tensor(5.6518, grad_fn=<SqrtBackward0>)
# tensor(5.2416, grad_fn=<SqrtBackward0>)
# tensor(5.4828, grad_fn=<SqrtBackward0>)
# tensor(5.7872, grad_fn=<SqrtBackward0>)
# tensor(5.2990, grad_fn=<SqrtBackward0>)
# tensor(6.2424, grad_fn=<SqrtBackward0>)
# tensor(4.6764, grad_fn=<SqrtBackward0>)
# tensor(5.3061, grad_fn=<SqrtBackward0>)
# tensor(6.1260, grad_fn=<SqrtBackward0>)
# tensor(4.3234, grad_fn=<SqrtBackward0>)
# tensor(5.1019, grad_fn=<SqrtBackward0>)
# tensor(5.4060, grad_fn=<SqrtBackward0>)
# tensor(5.9533, grad_fn=<SqrtBackward0>)
# tensor(4.9506, grad_fn=<SqrtBackward0>)
# tensor(4.5122, grad_fn=<SqrtBackward0>)
# tensor(5.1485, grad_fn=<SqrtBackward0>)
# tensor(4.9580, grad_fn=<SqrtBackward0>)
# tensor(6.0520, grad_fn=<SqrtBackward0>)
# tensor(5.0674, grad_fn=<SqrtBackward0>)
# tensor(6.4521, grad_fn=<SqrtBackward0>)
# tensor(6.3192, grad_fn=<SqrtBackward0>)
# tensor(5.0550, grad_fn=<SqrtBackward0>)
# tensor(4.4481, grad_fn=<SqrtBackward0>)
# tensor(4.8600, grad_fn=<SqrtBackward0>)
# tensor(5.9567, grad_fn=<SqrtBackward0>)
# tensor(5.6984, grad_fn=<SqrtBackward0>)
# tensor(5.7292, grad_fn=<SqrtBackward0>)
# tensor(5.6131, grad_fn=<SqrtBackward0>)
# tensor(5.2577, grad_fn=<SqrtBackward0>)
# tensor(5.3338, grad_fn=<SqrtBackward0>)
# tensor(6.0801, grad_fn=<SqrtBackward0>)
# tensor(4.9094, grad_fn=<SqrtBackward0>)
# tensor(4.6887, grad_fn=<SqrtBackward0>)
# tensor(5.6661, grad_fn=<SqrtBackward0>)
# tensor(5.5994, grad_fn=<SqrtBackward0>)
# tensor(5.0475, grad_fn=<SqrtBackward0>)
# tensor(5.2179, grad_fn=<SqrtBackward0>)
# tensor(6.1383, grad_fn=<SqrtBackward0>)
# tensor(6.3885, grad_fn=<SqrtBackward0>)
# tensor(4.4560, grad_fn=<SqrtBackward0>)
# tensor(5.1112, grad_fn=<SqrtBackward0>)
# tensor(5.4612, grad_fn=<SqrtBackward0>)
# tensor(5.6273, grad_fn=<SqrtBackward0>)
# tensor(3.9245, grad_fn=<SqrtBackward0>)
# tensor(4.8124, grad_fn=<SqrtBackward0>)
# tensor(4.2873, grad_fn=<SqrtBackward0>)
# tensor(3.8865, grad_fn=<SqrtBackward0>)
